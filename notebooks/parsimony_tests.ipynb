# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.10

# %%
import numpy as np
import pandas as pd
import feyn
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from functions import modsum, model_features_chart, crossvalidation_as_framework

feyn._qlattice._USE_V2_API=True

# %%
feyn.__version__
# Out:
# '2.1.3'

# %% [markdown]
# # AD Case

# %%
# Load the data
data = pd.read_csv("../data/ad_omics.csv")

# %%
# Define the semantic types
stypes = {}
for f in data.columns:
    if data[f].dtype =='object':
        stypes[f] = 'c'
        
# Set random seed for reproducibility
random_seed = 42

# %%
target = "_clinical AD diagnosis"

# %%
train_val, test = train_test_split(data, test_size=0.2, stratify=data[target], random_state=random_seed)

# %%
epochs = 50
criterion = 'wide_parsimony'
max_complexity = 10
random_seed = 42
sw = np.where(train_val[target] == 1, np.sum(train_val[target] == 0)/sum(train_val[target]), 1)

# %%
ql = feyn.connect_qlattice(server="https://qlattice.stage.abzu.ai") # Connecting
ql.reset(random_seed) # Resetting
models_single = ql.auto_run(data = train_val,
                         output_name = target,
                         kind = "classification",
                         stypes = stypes,
                         n_epochs = epochs,
                         criterion=criterion,
                         max_complexity = max_complexity,
                         sample_weights=sw)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <svg baseProfile="full" height="100.0" preserveAspectRatio="none" version="1.1" viewBox="0 0 445 100.0" width="445" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><svg class="graph" height="95.0" width="445" x="0" y="0"><defs /><text fill="#1E1E1E" font-family="monospace" font-size="12" text-anchor="middle" x="166.0" y="69.0">Loss: 3.09E-01</text><text fill="#1E1E1E" font-family="monospace" font-size="12" text-anchor="start" x="0" y="85.0">Epoch no. 50/50 - Tried 61946 models - Completed in 1m 56s.</text><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="121" y="20.0"><title>_clinical AD diagnosis
# logistic:
# w=2.6624
# bias=0.5883</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="166.0" y="41.5">_clinica..</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="209" y="29.0">0</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="123" y="29.0">out</text><line stroke="#1E1E1E" x1="91" x2="121" y1="37.5" y2="37.5" /><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="1" y="20.0"><title>MAPT
# linear:
# scale=0.000038
# scale offset=24135.487526
# w=2.939626
# bias=-0.2028</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="46.0" y="41.5">MAPT</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="89" y="29.0">1</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="3" y="29.0">num</text></svg></svg>

# %%
for m in models_single:
    print(m.wide_parsimony)
# Out:
# 117.5374361065451
# 119.5441047095184
# 119.87809028581316
# 120.35469954744758
# 120.58937033885454
# 121.11779638561347
# 124.22624321800942
# 124.26697833027842
# 124.42091175883573
# 124.57650845243117

# %%
for m in models_single:
    print(m.bic)
# Out:
# 67.35292573334159
# 69.3595943363149
# 69.69357991260966
# 70.17018917424407
# 70.40485996565104
# 70.93328601240997
# 74.0417328448059
# 74.08246795707491
# 74.23640138563222
# 74.39199807922766

# %% [markdown]
# ### Cross-validation as a framework

# %%
results_bic = crossvalidation_as_framework(data,
                                     target,
                                     kind = "classification",
                                     stypes = stypes,
                                     n_epochs = 50,
                                     criterion='bic',
                                     max_complexity = 10)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <svg baseProfile="full" height="280.0" preserveAspectRatio="none" version="1.1" viewBox="0 0 591 280.0" width="591" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><svg class="graph" height="275.0" width="591" x="0" y="0"><defs /><text fill="#1E1E1E" font-family="monospace" font-size="12" text-anchor="middle" x="526.0" y="159.0">Loss: 7.33E-02</text><text fill="#1E1E1E" font-family="monospace" font-size="12" text-anchor="start" x="0" y="265.0">Epoch no. 50/50 - Tried 59526 models - Completed in 2m 10s.</text><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="481" y="110.0"><title>_clinical AD diagnosis
# logistic:
# w=-18.6756
# bias=-0.1460</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="526.0" y="131.5">_clinica..</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="569" y="119.0">0</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="483" y="119.0">out</text><line stroke="#1E1E1E" x1="451" x2="481" y1="127.5" y2="127.5" /><rect class="node" fill="#FAFAFA" height="35" stroke="#FF1EC8" stroke-width="1" width="90" x="361" y="110.0"><title>add</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="406.0" y="131.5">add</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="449" y="119.0">1</text><line stroke="#1E1E1E" x1="331" x2="361" y1="97.5" y2="118.5" /><line stroke="#1E1E1E" x1="331" x2="361" y1="157.5" y2="136.5" /><rect class="node" fill="#FAFAFA" height="35" stroke="#FF1EC8" stroke-width="1" width="90" x="241" y="80.0"><title>add</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="286.0" y="101.5">add</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="329" y="89.0">2</text><line stroke="#1E1E1E" x1="211" x2="241" y1="97.5" y2="88.5" /><line stroke="#1E1E1E" x1="211" x2="241" y1="157.5" y2="106.5" /><rect class="node" fill="#FAFAFA" height="35" stroke="#FF1EC8" stroke-width="1" width="90" x="121" y="80.0"><title>add</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="166.0" y="101.5">add</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="209" y="89.0">3</text><line stroke="#1E1E1E" x1="91" x2="121" y1="37.5" y2="88.5" /><line stroke="#1E1E1E" x1="91" x2="121" y1="97.5" y2="106.5" /><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="1" y="20.0"><title>CALR
# linear:
# scale=0.000004
# scale offset=300372.164205
# w=0.385791
# bias=-0.7167</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="46.0" y="41.5">CALR</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="89" y="29.0">4</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="3" y="29.0">num</text><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="1" y="80.0"><title>SERPINE2.1
# linear:
# scale=0.000049
# scale offset=24165.661276
# w=-0.269938
# bias=-0.2306</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="46.0" y="101.5">SERPINE2.1</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="89" y="89.0">5</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="3" y="89.0">num</text><rect class="node" fill="#FAFAFA" height="35" stroke="#FF1EC8" stroke-width="1" width="90" x="121" y="140.0"><title>gaussian2</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="166.0" y="161.5">gaussian</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="209" y="149.0">6</text><line stroke="#1E1E1E" x1="91" x2="121" y1="157.5" y2="148.5" /><line stroke="#1E1E1E" x1="91" x2="121" y1="217.5" y2="166.5" /><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="1" y="140.0"><title>MAPT
# linear:
# scale=0.000034
# scale offset=23872.303152
# w=-1.178576
# bias=-0.3746</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="46.0" y="161.5">MAPT</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="89" y="149.0">7</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="3" y="149.0">num</text><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="1" y="200.0"><title>YWHAG
# linear:
# scale=0.000021
# scale offset=38921.275040
# w=2.108955
# bias=0.4624</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="46.0" y="221.5">YWHAG</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="89" y="209.0">8</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="3" y="209.0">num</text><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="241" y="140.0"><title>PON1
# linear:
# scale=0.000002
# scale offset=467479.150355
# w=0.287096
# bias=0.6700</title></rect><text fill="#1E1E1E" font-family="monospace" font-size="12" style="pointer-events:none" text-anchor="middle" x="286.0" y="161.5">PON1</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="end" x="329" y="149.0">9</text><text fill="#1E1E1E" font-family="monospace" font-size="10" style="pointer-events:none" text-anchor="start" x="243" y="149.0">num</text></svg></svg>

# %%
results_bic
# Out:
#                                      model_structure fold        aic  \
# 0  logreg(HSPA8 + (IGLV4-69 + LDHB + MAPT + SST)**2)    0  10.005911
# 0          logreg(C1R + GSTP1 + (CNTNAP4 + MAPT)**2)    0  21.278180
# 0      logreg(A2M + EPHA4 + MAPT + log(GPI + YWHAG))    0  19.690722
# 0                     logreg(GPC1 + LTA4H + MAPT**2)    0  25.577988
# 0                  logreg(IGLV4-69 + MAPT**2 + NBL1)    0  28.332177
# 0                         logreg(IGLV4-69 + MAPT**2)    0  32.618145
# 0          logreg(HEXB + IGLV4-69 + MAPT**2 + PTPRN)    0  27.482325
# 0                    logreg(FSTL1 + MAPT**2 + YWHAG)    0  30.565728
# 0                            logreg(MAPT**2 + ROBO1)    0  34.487910
# 0                            logreg(CRP + exp(MAPT))    0  35.281605
# 0                logreg(ENOPH1 + (ENDOD1 + MAPT)**2)    1  39.382601
# 0                           logreg(ENDOD1 + MAPT**2)    1  45.128451
# 0                     logreg(AGRN + MAPT*hCG2039566)    1  43.569156
# 0                   logreg(TAC3 + (MAPT + NXPH3)**2)    1  44.278526
# 0               logreg(PTPRF + (IGLV4-69 + MAPT)**2)    1  44.439506
# 0                          logreg(CRP + MAPT + NID1)    1  48.384947
# 0                   logreg(CLU*MAPT + GDI2 + SPOCK2)    1  43.175430
# 0                       logreg((IGLV4-69 + MAPT)**2)    1  48.605566
# 0                 logreg(APLP1 + CP*IGHV4-34 + MAPT)    1  43.460665
# 0                          logreg((CBLN1 + MAPT)**2)    1  48.893566
# 0           logreg(ENOPH1 + LILRA2 + MAPT**2 + NID2)    2  26.257798
# 0                logreg((IGLV4-69 + MAPT + THY1)**2)    2  40.610555
# 0        logreg(MAPT + exp(ATP6AP2*IGLC3 + THY1**2))    2  32.688757
# 0    logreg(log(AGRN + LILRA2 + YWHAG + tanh(MAPT)))    2  36.170292
# 0                  logreg(IGLV4-69 + MAPT**2 + NID2)    2  44.734128
# 0                 logreg(IGLV4-69 + MAPT*hCG2039566)    2  48.540409
# 0  logreg(MAPT**2 + WFIKKN2 + age at CSF collection)    2  48.706907
# 0                         logreg(IGLV4-69 + MAPT**2)    2  51.675233
# 0    logreg(CDH6 + hCG2039566 + tanh(ENOPH1 + MAPT))    2  47.765251
# 0                   logreg((LILRA2 + MAPT + NOV)**2)    2  51.612091
# 0  logreg(CCK + IGKV1D-33 + IGLV4-69*NCAN + tanh(...    3  34.520840
# 0                  logreg(IGLV4-69 + MAPT**2 + THY1)    3  43.261135
# 0                   logreg(PVR + (LILRA2 + MAPT)**2)    3  44.576435
# 0        logreg(CCK + IGLV4-69 + LAMB4 + tanh(MAPT))    3  42.773092
# 0                           logreg(LILRA2 + MAPT**2)    3  48.867596
# 0                         logreg((LILRA2 + MAPT)**2)    3  50.714999
# 0  logreg(GAPDH + MAPT + PRSS3 + THY1 + age at CS...    3  46.541945
# 0                       logreg((IGLV4-69 + MAPT)**2)    3  54.484803
# 0                         logreg(IGLV4-69 + MAPT**2)    3  54.885862
# 0        logreg((IGHV3-38 + MAPT)**2 + tanh(PCSK1N))    3  50.219091
# 0  logreg(CALR + PON1 + SERPINE2.1 + exp(-MAPT**2...    4  30.123576
# 0  logreg(MAPT + ROBO2 + SERPINE2.1 + SULF2 + hCG...    4  43.540518
# 0            logreg(ENDOD1 + GPR158 + MAPT + METRNL)    4  46.721030
# 0                              logreg(LILRA2 + MAPT)    4  52.935729
# 0  logreg(GAS6 + GPC1 + MAPT + age at CSF collect...    4  48.036654
# 0            logreg(APLP1 + IGHV3-38 + MAPT + SRSF7)    4  52.152219
# 0         logreg(AP2B1 + ENPP4 + MAPT + tanh(YWHAG))    4  49.545741
# 0      logreg(MAPT + SEZ6L2 + age at CSF collection)    4  55.164462
# 0                      logreg(APLP1 + IGFBP6 + MAPT)    4  57.646228
# 0                              logreg(ENDOD1 + MAPT)    4  60.450724
#
#          bic  roc_auc_train  accuracy_train  roc_auc_val  accuracy_val  \
# 0  23.462650       1.000000        1.000000     0.872222      0.750000
# 0  32.043571       0.997802        0.972477     0.788889      0.750000
# 0  33.147462       0.999634        0.990826     0.861111      0.857143
# 0  33.652031       0.993407        0.981651     0.844444      0.750000
# 0  36.406221       0.993773        0.954128     0.900000      0.750000
# 0  38.000841       0.991209        0.954128     0.877778      0.785714
# 0  38.247716       0.995238        0.972477     0.883333      0.785714
# 0  38.639771       0.993040        0.972477     0.877778      0.857143
# 0  39.870606       0.988278        0.954128     0.833333      0.785714
# 0  40.664301       0.989377        0.944954     0.872222      0.785714
# 0  47.456645       0.985348        0.917431     0.950000      0.785714
# 0  50.511147       0.975092        0.926606     0.938889      0.821429
# 0  51.643200       0.969231        0.926606     0.961111      0.857143
# 0  52.352569       0.979487        0.944954     0.938889      0.821429
# 0  52.513550       0.977289        0.954128     0.972222      0.857143
# 0  53.767643       0.978388        0.935780     0.950000      0.892857
# 0  53.940822       0.982418        0.944954     0.905556      0.785714
# 0  53.988262       0.974359        0.926606     0.972222      0.892857
# 0  54.226057       0.979853        0.935780     0.833333      0.750000
# 0  54.276262       0.970330        0.926606     0.861111      0.785714
# 0  37.059720       0.995357        0.972727     0.975309      0.925926
# 0  48.711996       0.985000        0.954545     0.969136      0.962963
# 0  48.891639       0.994643        0.954545     0.858025      0.888889
# 0  49.672694       0.981786        0.990909     1.000000      1.000000
# 0  52.835569       0.981071        0.936364     0.981481      0.888889
# 0  56.641850       0.977143        0.918182     1.000000      0.962963
# 0  56.808348       0.973214        0.936364     0.969136      0.814815
# 0  57.076194       0.970357        0.900000     0.987654      0.962963
# 0  58.567173       0.980714        0.927273     0.981481      0.962963
# 0  59.713532       0.972143        0.900000     0.987654      0.888889
# 0  50.723722       0.992055        0.972727     0.952941      0.925926
# 0  51.362576       0.982665        0.927273     1.000000      0.851852
# 0  52.677877       0.979054        0.936364     0.988235      0.814815
# 0  53.575013       0.982304        0.945455     0.988235      0.925926
# 0  54.268557       0.969303        0.909091     0.982353      0.888889
# 0  56.115960       0.966775        0.900000     0.994118      0.925926
# 0  57.343866       0.985193        0.936364     0.947059      0.888889
# 0  59.885763       0.968942        0.909091     1.000000      0.888889
# 0  60.286822       0.968220        0.900000     1.000000      0.888889
# 0  61.021013       0.975442        0.936364     1.000000      0.851852
# 0  49.026939       0.997472        0.972727     0.905882      0.814815
# 0  54.342440       0.978693        0.918182     0.894118      0.851852
# 0  54.822471       0.978332        0.936364     0.941176      0.962963
# 0  55.636210       0.963525        0.918182     0.917647      0.925926
# 0  56.138095       0.971109        0.927273     0.958824      0.925926
# 0  60.253660       0.970748        0.927273     0.941176      0.962963
# 0  60.347663       0.975442        0.927273     0.905882      0.814815
# 0  60.565423       0.969303        0.890909     0.923529      0.925926
# 0  63.047189       0.963164        0.900000     0.941176      0.925926
# 0  63.151204       0.956302        0.854545     0.941176      0.925926
#
#      pr_auc        f1                                       query_string
# 0  0.856864  0.600000  add("HSPA8", squared(add(add("MAPT", add("LDHB...
# 0  0.656294  0.645161  add(squared(add("MAPT", "CNTNAP4")), add("GSTP...
# 0  0.838204  0.600000  add(add(add("EPHA4", "MAPT"), log(add("YWHAG",...
# 0  0.823283  0.620690         add(add(squared("MAPT"), "GPC1"), "LTA4H")
# 0  0.863737  0.666667      add(squared("MAPT"), add("NBL1", "IGLV4-69"))
# 0  0.841198  0.642857                   add("IGLV4-69", squared("MAPT"))
# 0  0.851428  0.642857  add("PTPRN", add(add("IGLV4-69", squared("MAPT...
# 0  0.848334  0.666667        add(add(squared("MAPT"), "YWHAG"), "FSTL1")
# 0  0.778578  0.642857                      add(squared("MAPT"), "ROBO1")
# 0  0.786315  0.740741                            add(exp("MAPT"), "CRP")
# 0  0.903286  0.666667      add(squared(add("MAPT", "ENDOD1")), "ENOPH1")
# 0  0.902164  0.625000                     add(squared("MAPT"), "ENDOD1")
# 0  0.928981  0.714286       add(multiply("MAPT", "hCG_2039566"), "AGRN")
# 0  0.881512  0.689655         add(squared(add("MAPT", "NXPH3")), "TAC3")
# 0  0.951679  0.833333     add("PTPRF", squared(add("MAPT", "IGLV4-69")))
# 0  0.909151  0.740741                    add(add("MAPT", "NID1"), "CRP")
# 0  0.882496  0.645161  add(multiply("MAPT", "CLU"), add("GDI2", "SPOC...
# 0  0.946822  0.714286                   squared(add("IGLV4-69", "MAPT"))
# 0  0.828503  0.600000  add(add("MAPT", "APLP1"), multiply("CP", "IGHV...
# 0  0.836787  0.588235                      squared(add("CBLN1", "MAPT"))
# 0  0.943078  0.666667  add(add(add(squared("MAPT"), "NID2"), "ENOPH1"...
# 0  0.958791  0.782609      squared(add(add("MAPT", "IGLV4-69"), "THY1"))
# 0  0.858542  0.640000  add(exp(add(squared("THY1"), multiply("IGLC3",...
# 0  1.000000  0.620690  log(add("AGRN", add(add("YWHAG", tanh("MAPT"))...
# 0  0.960273  0.782609      add(add(squared("MAPT"), "IGLV4-69"), "NID2")
# 0  1.000000  0.750000   add(multiply("MAPT", "hCG_2039566"), "IGLV4-69")
# 0  0.940450  0.818182  add("_age at CSF collection", add(squared("MAP...
# 0  0.978788  0.750000                   add("IGLV4-69", squared("MAPT"))
# 0  0.970960  0.750000  add("hCG_2039566", add(tanh(add("MAPT", "ENOPH...
# 0  0.975154  0.750000         squared(add("NOV", add("MAPT", "LILRA2")))
# 0  0.954248  0.606061  add(add(add("CCK", "IGKV1D-33"), tanh("MAPT"))...
# 0  1.000000  0.606061      add(add("IGLV4-69", squared("MAPT")), "THY1")
# 0  0.979899  0.625000         add(squared(add("MAPT", "LILRA2")), "PVR")
# 0  0.982576  0.606061  add(tanh("MAPT"), add(add("LAMB4", "IGLV4-69")...
# 0  0.972020  0.606061                     add(squared("MAPT"), "LILRA2")
# 0  0.990455  0.606061                     squared(add("LILRA2", "MAPT"))
# 0  0.900766  0.689655  add("_age at CSF collection", add("THY1", add(...
# 0  1.000000  0.625000                   squared(add("IGLV4-69", "MAPT"))
# 0  1.000000  0.625000                   add(squared("MAPT"), "IGLV4-69")
# 0  1.000000  0.571429  add(squared(add("IGHV3-38", "MAPT")), tanh("PC...
# 0  0.811834  0.645161  add(add(add("CALR", "SERPINE2.1"), gaussian("M...
# 0  0.707816  0.666667  add(add("SERPINE2.1", add(add("MAPT", "hCG_203...
# 0  0.752558  0.666667  add(add(add("GPR158", "METRNL"), "MAPT"), "END...
# 0  0.727579  0.645161                              add("LILRA2", "MAPT")
# 0  0.898391  0.645161  add(add("MAPT", add("_age at CSF collection", ...
# 0  0.752558  0.689655  add(add("APLP1", "MAPT"), add("SRSF7", "IGHV3-...
# 0  0.830783  0.625000  add("MAPT", add("ENPP4", add(tanh("YWHAG"), "A...
# 0  0.726838  0.689655  add(add("_age at CSF collection", "MAPT"), "SE...
# 0  0.752558  0.689655                add(add("APLP1", "MAPT"), "IGFBP6")
# 0  0.752558  0.625000                              add("ENDOD1", "MAPT")

# %%
results_wide_parsimony = crossvalidation_as_framework(data,
                                     target,
                                     kind = "classification",
                                     stypes = stypes,
                                     n_epochs = 50,
                                     criterion='wide_parsimony',
                                     max_complexity = 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l5/mw2x7c910_57fpww4k2pxjhw0000gn/T/ipykernel_69517/3100239473.py in <module>
# ----> 1 results_wide_parsimony = crossvalidation_as_framework(data,
#       2                                      target,
#       3                                      kind = "classification",
#       4                                      stypes = stypes,
#       5                                      n_epochs = 50,
#
# ~/repos/qlattice-clinical-omics-paper/notebooks/functions.py in crossvalidation_as_framework(df, target, n_folds, random_state, use_sample_weights, **kwargs)
#      29
#      30         for j in models:
# ---> 31             results.update(train, val, i, j)
#      32
#      33     return results.df
#
# ~/repos/qlattice-clinical-omics-paper/notebooks/functions.py in update(self, train, val, fold, model)
#      49         if model:
#      50             if self.kind == "classification":
# ---> 51                 model_precision, model_recall, _ = precision_recall_curve(val[model.output], model.predict(val))
#      52                 if model:
#      53                     self.df = self.df.append(pd.DataFrame(data={
#
# ~/repos/qmodel/feyn/feyn/_model.py in predict(self, X)
#     188             np.ndarray -- The calculated predictions.
#     189         """
# --> 190         activations = self._get_activations(X, protected=True)
#     191         return activations[0]
#     192
#
# ~/repos/qmodel/feyn/feyn/_model.py in _get_activations(self, X, protected)
#     216         # Magic support for pandas DataFrame
#     217         if type(X).__name__ == "DataFrame":
# --> 218             X = {col: X[col].values for col in X.columns}
#     219
#     220         func_key = "func_protected" if protected else "func"
#
# ~/repos/qmodel/feyn/feyn/_model.py in <dictcomp>(.0)
#     216         # Magic support for pandas DataFrame
#     217         if type(X).__name__ == "DataFrame":
# --> 218             X = {col: X[col].values for col in X.columns}
#     219
#     220         func_key = "func_protected" if protected else "func"
#
# ~/repos/qmodel/feyn/venv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3425                 if isinstance(self.columns, MultiIndex):
#    3426                     return self._getitem_multilevel(key)
# -> 3427                 return self._get_item_cache(key)
#    3428
#    3429         # Do we have a slicer (on rows)?
#
# ~/repos/qmodel/feyn/venv/lib/python3.8/site-packages/pandas/core/frame.py in _get_item_cache(self, item)
#    3884             loc = self.columns.get_loc(item)
#    3885             values = self._mgr.iget(loc)
# -> 3886             res = self._box_col_values(values, loc).__finalize__(self)
#    3887
#    3888             cache[item] = res
#
# ~/repos/qmodel/feyn/venv/lib/python3.8/site-packages/pandas/core/generic.py in __finalize__(self, other, method, **kwargs)
#    5457                 self.attrs[name] = other.attrs[name]
#    5458
# -> 5459             self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    5460             # For subclasses using _metadata.
#    5461             for name in set(self._metadata) & set(other._metadata):
#
# KeyboardInterrupt:

# %%
results_bic.groupby("fold").first().roc_auc_val.mean(), results_bic.groupby("fold").first().accuracy_val.mean()

# %%
results_wide_parsimony.groupby("fold").first().roc_auc_val.mean(), results_wide_parsimony.groupby("fold").first().accuracy_val.mean()

# %% [markdown]
# # BC case

# %%
data_bc = pd.read_csv('../data/brca_data_w_meta.csv')
 
# Define the target variable
target = "vital.status"

stypes = {}
for f in data_bc.columns:
    if data_bc[f].dtype == 'object':
        stypes[f] = 'c'

# %%
results_bic_bc = pd.DataFrame(columns=['model_structure', 'fold', 'aic', 'bic', 'roc_auc_train',
                                            'accuracy_train', 'roc_auc_val', 'accuracy_val', 'pr_auc', 'f1'])

for i in range(3):
    res = crossvalidation_as_framework(data_bc,
                                     target,
                                     kind = "classification",
                                     stypes = stypes,
                                     n_epochs = 50,
                                     criterion='bic',
                                     max_complexity = 10,
                                     random_state = i)
    
    results_bic_bc = results_bic_bc.append(res)

# %%
results_wide_parsimony_bc = pd.DataFrame(columns=['model_structure', 'fold', 'aic', 'bic', 'roc_auc_train',
                                            'accuracy_train', 'roc_auc_val', 'accuracy_val', 'pr_auc', 'f1'])

for i in range(3):
    res = crossvalidation_as_framework(data_bc,
                                     target,
                                     kind = "classification",
                                     stypes = stypes,
                                     n_epochs = 50,
                                     criterion='wide_parsimony',
                                     max_complexity = 10,
                                     random_state = i)
    
    results_wide_parsimony_bc = results_wide_parsimony_bc.append(res)

# %%
results_bic_bc.roc_auc_val.mean(), results_bic_bc.accuracy_val.mean()

# %%
results_wide_parsimony_bc.roc_auc_val.mean(), results_wide_parsimony_bc.accuracy_val.mean()

# %%
len(results_bic_bc)
